# %% [markdown]
# # PyKeen

# %%
pip install pykeen rdflib torch scikit-learn
# Out:
# Requirement already satisfied: pykeen in c:\users\kai\anaconda3\lib\site-packages (1.11.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: rdflib in c:\users\kai\anaconda3\lib\site-packages (7.4.0)
# Requirement already satisfied: torch in c:\users\kai\anaconda3\lib\site-packages (2.6.0)
# Requirement already satisfied: scikit-learn in c:\users\kai\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: dataclasses-json in c:\users\kai\anaconda3\lib\site-packages (from pykeen) (0.6.7)
# Requirement already satisfied: numpy in c:\users\kai\anaconda3\lib\site-packages (from pykeen) (1.26.4)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\kai\anaconda3\lib\site-packages (from pykeen) (1.13.1)
# Requirement already satisfied: click in c:\users\kai\anaconda3\lib\site-packages (from pykeen) (8.1.7)
# Requirement already satisfied: click_default_group in c:\users\kai\anaconda3\lib\site-packages (from pykeen) (1.2.4)
# Requirement already satisfied: tqdm in c:\users\kai\anaconda3\lib\site-packages (from pykeen) (4.66.4)
# Requirement already satisfied: requests in c:\users\kai\anaconda3\lib\site-packages (from pykeen) (2.32.2)
# Requirement already satisfied: optuna>=2.0.0 in c:\users\kai\anaconda3\lib\site-packages (from pykeen) (4.5.0)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\kai\anaconda3\lib\site-packages (from pykeen) (2.2.2)
# Requirement already satisfied: tabulate in c:\users\kai\anaconda3\lib\site-packages (from pykeen) (0.9.0)
# Requirement already satisfied: more_click in c:\users\kai\anaconda3\lib\site-packages (from pykeen) (0.1.3)
# Requirement already satisfied: more_itertools in c:\users\kai\anaconda3\lib\site-packages (from pykeen) (10.1.0)
# Requirement already satisfied: pystow>=0.4.3 in c:\users\kai\anaconda3\lib\site-packages (from pykeen) (0.7.11)
# Requirement already satisfied: docdata>=0.0.5 in c:\users\kai\anaconda3\lib\site-packages (from pykeen) (0.0.5)
# Requirement already satisfied: class_resolver>=0.6.0 in c:\users\kai\anaconda3\lib\site-packages (from pykeen) (0.7.1)
# Requirement already satisfied: pyyaml in c:\users\kai\anaconda3\lib\site-packages (from pykeen) (6.0.1)
# Requirement already satisfied: torch_max_mem>=0.1.4 in c:\users\kai\anaconda3\lib\site-packages (from pykeen) (0.1.4)
# Requirement already satisfied: torch-ppr>=0.0.7 in c:\users\kai\anaconda3\lib\site-packages (from pykeen) (0.0.8)
# Requirement already satisfied: typing_extensions in c:\users\kai\anaconda3\lib\site-packages (from pykeen) (4.13.0)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in c:\users\kai\anaconda3\lib\site-packages (from rdflib) (3.0.9)
# Requirement already satisfied: filelock in c:\users\kai\anaconda3\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: networkx in c:\users\kai\anaconda3\lib\site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\kai\anaconda3\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\kai\anaconda3\lib\site-packages (from torch) (2024.3.1)
# Requirement already satisfied: setuptools in c:\users\kai\anaconda3\lib\site-packages (from torch) (69.5.1)
# Requirement already satisfied: sympy==1.13.1 in c:\users\kai\anaconda3\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\kai\anaconda3\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\kai\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\kai\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\kai\anaconda3\lib\site-packages (from optuna>=2.0.0->pykeen) (1.17.1)
# Requirement already satisfied: colorlog in c:\users\kai\anaconda3\lib\site-packages (from optuna>=2.0.0->pykeen) (6.10.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\kai\anaconda3\lib\site-packages (from optuna>=2.0.0->pykeen) (23.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\users\kai\anaconda3\lib\site-packages (from optuna>=2.0.0->pykeen) (2.0.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kai\anaconda3\lib\site-packages (from pandas>=1.0.0->pykeen) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kai\anaconda3\lib\site-packages (from pandas>=1.0.0->pykeen) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kai\anaconda3\lib\site-packages (from pandas>=1.0.0->pykeen) (2023.3)
# Requirement already satisfied: colorama in c:\users\kai\anaconda3\lib\site-packages (from click->pykeen) (0.4.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\kai\anaconda3\lib\site-packages (from dataclasses-json->pykeen) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\kai\anaconda3\lib\site-packages (from dataclasses-json->pykeen) (0.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kai\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kai\anaconda3\lib\site-packages (from requests->pykeen) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kai\anaconda3\lib\site-packages (from requests->pykeen) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kai\anaconda3\lib\site-packages (from requests->pykeen) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kai\anaconda3\lib\site-packages (from requests->pykeen) (2024.7.4)
# Requirement already satisfied: Mako in c:\users\kai\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna>=2.0.0->pykeen) (1.3.10)
# Requirement already satisfied: six>=1.5 in c:\users\kai\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->pykeen) (1.16.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\kai\anaconda3\lib\site-packages (from sqlalchemy>=1.4.2->optuna>=2.0.0->pykeen) (3.0.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\kai\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->pykeen) (1.0.0)

# %%
import zipfile
from rdflib import Graph
import pandas as pd
from pykeen.triples import TriplesFactory
import numpy as np
from pykeen.pipeline import pipeline

# %%
kgPath = "ESCOdataset.rdf.zip"
rdf_inner_name = "esco-v1.2.0.rdf" # idk why this name is different but it is -_-
g = Graph()
g.parse("esco.nt", format = "nt")

skill_query = """
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX esco: <http://data.europa.eu/esco/model#>

SELECT ?skill ?label
WHERE {
  # ?skill a esco:Skill ;
         skos:prefLabel ?label .
  FILTER (lang(?label) = "en")
}
"""

skills = list(g.query(skill_query))
print(f"Number of triples: {len (g)}")
print("Number of skills:", len(skills))

skill_uris = []
skill_labels = []

for row in skills:
    skill_uris.append(str(row.skill))
    skill_labels.append(str(row.label))
# Out:
# Number of triples: 8756008
# Number of skills: 14257

# %% [markdown]
# We only extract those tuples related to the skills directly (i.e. direct neighbours), because if we try to learn to model for all the data, it wants 377.gib allocated :).

# %%
import pandas as pd

skill_uri_set = set(skill_uris)

triples = []

for s, p, o in g:
    s = str(s)
    p = str(p)
    o = str(o)
    
    # Keep triples where at least one side is a skill
    if s in skill_uri_set or o in skill_uri_set:
        triples.append((s, p, o))

print("Triples involving at least one skill:", len(triples))

df_triples = pd.DataFrame(triples, columns=["head", "relation", "tail"])
# Out:
# Triples involving at least one skill: 2440814

# %%
from pykeen.triples import TriplesFactory
import numpy as np

# PyKEEN expects shape (n_triples, 3) as a numpy array of strings
labeled_triples = df_triples[["head", "relation", "tail"]].values.astype(str)

tf = TriplesFactory.from_labeled_triples(labeled_triples)
print("#entities:", tf.num_entities)
print("#relations:", tf.num_relations)
# Out:
# #entities: 1738720
# #relations: 30

# %%
train_tf, test_tf, valid_tf = tf.split([0.8, 0.1, 0.1])

result = pipeline(
    training=train_tf,
    testing=test_tf,
    validation=valid_tf,
    model="ComplEx",             # or "TransE", "DistMult", ...
    model_kwargs=dict(embedding_dim=100),
    training_kwargs=dict(
        num_epochs=50,           # start small to test
        batch_size=1024,
    ),
    stopper="early",             # optional early stopping
    random_seed = 42,
    use_tqdm = True
)

model = result.model
# Out:
# WARNING:pykeen.utils:using automatically assigned random_state=2112452299
# INFO:pykeen.triples.splitting:done splitting triples to groups of sizes [193588, 241537, 241538]
# WARNING:pykeen.utils:No cuda devices were available. The model runs on CPU
# INFO:pykeen.pipeline.api:Using device: None
# INFO:pykeen.nn.representation:Inferred unique=False for Embedding(
#   (regularizer): LpRegularizer()
# )
# INFO:pykeen.nn.representation:Inferred unique=False for Embedding(
#   (regularizer): LpRegularizer()
# )
# INFO:pykeen.stoppers.early_stopping:Inferred checkpoint path for best model weights: C:\Users\Kai\.data\pykeen\checkpoints\best-model-weights-c5431354-6a82-4c4f-90cc-8d99e9ab5cab.pt
# Training epochs on cpu:   0%|          | 0/50 [00:00<?, ?epoch/s]
# Training batches on cpu:   0%|          | 0.00/1.89k [00:00<?, ?batch/s]

# %%
entity_to_id = tf.entity_to_id

skill_entity_ids = []
skill_entity_labels = []
skill_entity_uris_in_tf = []

for uri, label in zip(skill_uris, skill_labels):
    if uri in entity_to_id:
        skill_entity_ids.append(entity_to_id[uri])
        skill_entity_labels.append(label)
        skill_entity_uris_in_tf.append(uri)

print("Skills that appear as entities in the TriplesFactory:", len(skill_entity_ids))

skill_entity_ids_tensor = torch.as_tensor(skill_entity_ids, dtype=torch.long)
