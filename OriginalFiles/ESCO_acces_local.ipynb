# %% [markdown]
# # ESCO Dataset

# %% [markdown]
# Stuff todo:
# 1. load as indexed graph --> pyoxiograph
# 2. find potentially other datasources
# 3. check on tuesday if this use case is accepted, so we don't do the work for nothing

# %%
pip install rdflib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
print("Kernel Python:", sys.version)
print("Executable:", sys.executable)

# install into THIS kernel
# !{sys.executable} -m pip install -U pip setuptools wheel
# !{sys.executable} -m pip install -U pyoxigraph

# verify pip sees it here
# !{sys.executable} -m pip show pyoxigraph
# Out:
# Kernel Python: 3.13.4 (tags/v3.13.4:8a526ec, Jun  3 2025, 17:46:04) [MSC v.1943 64 bit (AMD64)]
# Executable: c:\Users\Kai\AppData\Local\Programs\Python\Python313\python.exe
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----------------------- ---------------- 1.0/1.8 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 3.5 MB/s eta 0:00:00
# ...
#
#    ---------------------------------------- 0/2 [wheel]
#    ---------------------------------------- 0/2 [wheel]
#    ---------------------------------------- 0/2 [wheel]
#    ---------------------------------------- 0/2 [wheel]
#    ---------------------------------------- 0/2 [wheel]
#    ---------------------------------------- 0/2 [wheel]
#    ---------------------------------------- 0/2 [wheel]
#   Attempting uninstall: pip
#    ---------------------------------------- 0/2 [wheel]
# ...

# %%
from pyoxigraph import Store, RdfFormat

store = Store()

# Open the file manually as a binary stream
with open("ESCO_data/esco-v1.2.0.rdf", "rb") as f:
    store.load(f, RdfFormat.RDF_XML)
