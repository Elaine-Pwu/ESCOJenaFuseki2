# %% [markdown]
# https://github.com/NathanDestrez/DS_Mission/blob/main/Ds_Mission_Final_DataCraft2.ipynb

# %%
pip install neo4j
# Out:
# Collecting neo4j
#   Downloading neo4j-6.0.2-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: pytz in c:\users\kai\appdata\local\programs\python\python313\lib\site-packages (from neo4j) (2025.2)
# Downloading neo4j-6.0.2-py3-none-any.whl (325 kB)
# Installing collected packages: neo4j
# Successfully installed neo4j-6.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install py2neo
# Out:
# Collecting py2neo
#   Downloading py2neo-2021.2.4-py2.py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: certifi in c:\users\kai\appdata\local\programs\python\python313\lib\site-packages (from py2neo) (2025.4.26)
# Collecting interchange~=2021.0.4 (from py2neo)
#   Downloading interchange-2021.0.4-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting monotonic (from py2neo)
#   Downloading monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: packaging in c:\users\kai\appdata\local\programs\python\python313\lib\site-packages (from py2neo) (24.2)
# Collecting pansi>=2020.7.3 (from py2neo)
#   Downloading pansi-2024.11.0-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: pygments>=2.0.0 in c:\users\kai\appdata\roaming\python\python313\site-packages (from py2neo) (2.19.2)
# Requirement already satisfied: six>=1.15.0 in c:\users\kai\appdata\local\programs\python\python313\lib\site-packages (from py2neo) (1.17.0)
# Requirement already satisfied: urllib3 in c:\users\kai\appdata\local\programs\python\python313\lib\site-packages (from py2neo) (2.4.0)
# Requirement already satisfied: pytz in c:\users\kai\appdata\local\programs\python\python313\lib\site-packages (from interchange~=2021.0.4->py2neo) (2025.2)
# Requirement already satisfied: pillow in c:\users\kai\appdata\local\programs\python\python313\lib\site-packages (from pansi>=2020.7.3->py2neo) (11.2.1)
# Downloading py2neo-2021.2.4-py2.py3-none-any.whl (177 kB)
# Downloading interchange-2021.0.4-py2.py3-none-any.whl (28 kB)
# Downloading pansi-2024.11.0-py2.py3-none-any.whl (26 kB)
# Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Installing collected packages: monotonic, pansi, interchange, py2neo
#
#    ---------- ----------------------------- 1/4 [pansi]
#    -------------------- ------------------- 2/4 [interchange]
#    ------------------------------ --------- 3/4 [py2neo]
#    ------------------------------ --------- 3/4 [py2neo]
#    ------------------------------ --------- 3/4 [py2neo]
#    ------------------------------ --------- 3/4 [py2neo]
#    ------------------------------ --------- 3/4 [py2neo]
#    ---------------------------------------- 4/4 [py2neo]
#
# Successfully installed interchange-2021.0.4 monotonic-1.6 pansi-2024.11.0 py2neo-2021.2.4
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install neomodel
# Out:
# Collecting neomodel
#   Downloading neomodel-5.5.3-py3-none-any.whl.metadata (9.7 kB)
# Collecting neo4j~=5.28.2 (from neomodel)
#   Downloading neo4j-5.28.2-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: pytz in c:\users\kai\appdata\local\programs\python\python313\lib\site-packages (from neo4j~=5.28.2->neomodel) (2025.2)
# Downloading neomodel-5.5.3-py3-none-any.whl (240 kB)
# Downloading neo4j-5.28.2-py3-none-any.whl (313 kB)
# Installing collected packages: neo4j, neomodel
#
#   Attempting uninstall: neo4j
#
#     Found existing installation: neo4j 6.0.2
#
#     Uninstalling neo4j-6.0.2:
#
#       Successfully uninstalled neo4j-6.0.2
#
#    ---------------------------------------- 0/2 [neo4j]
#    ---------------------------------------- 0/2 [neo4j]
#    ---------------------------------------- 0/2 [neo4j]
#    ---------------------------------------- 0/2 [neo4j]
#    ---------------------------------------- 0/2 [neo4j]
#    ---------------------------------------- 0/2 [neo4j]
#    ---------------------------------------- 0/2 [neo4j]
#    ---------------------------------------- 0/2 [neo4j]
#    ---------------------------------------- 0/2 [neo4j]
#    ---------------------------------------- 0/2 [neo4j]
#    ---------------------------------------- 0/2 [neo4j]
#    ---------------------------------------- 0/2 [neo4j]
#    ---------------------------------------- 0/2 [neo4j]
#    ---------------------------------------- 0/2 [neo4j]
#    ---------------------------------------- 0/2 [neo4j]
#    ---------------------------------------- 0/2 [neo4j]
#    -------------------- ------------------- 1/2 [neomodel]
#    -------------------- ------------------- 1/2 [neomodel]
#    -------------------- ------------------- 1/2 [neomodel]
#    -------------------- ------------------- 1/2 [neomodel]
#    -------------------- ------------------- 1/2 [neomodel]
#    -------------------- ------------------- 1/2 [neomodel]
#    -------------------- ------------------- 1/2 [neomodel]
#    -------------------- ------------------- 1/2 [neomodel]
#    -------------------- ------------------- 1/2 [neomodel]
#    -------------------- ------------------- 1/2 [neomodel]
#    -------------------- ------------------- 1/2 [neomodel]
#    -------------------- ------------------- 1/2 [neomodel]
#    -------------------- ------------------- 1/2 [neomodel]
#    -------------------- ------------------- 1/2 [neomodel]
#    -------------------- ------------------- 1/2 [neomodel]
#    -------------------- ------------------- 1/2 [neomodel]
#    -------------------- ------------------- 1/2 [neomodel]
#    -------------------- ------------------- 1/2 [neomodel]
#    -------------------- ------------------- 1/2 [neomodel]
#    ---------------------------------------- 2/2 [neomodel]
#
# Successfully installed neo4j-5.28.2 neomodel-5.5.3
# Note: you may need to restart the kernel to use updated packages.

# %%
#Scrap 

import requests #Requests allows to send HTTP/1.1 requests

#Utilitaires 
import json
import pandas as pd
import numpy as np
from pandas import json_normalize

from concurrent.futures import ThreadPoolExecutor

#Neo4j

from neo4j import GraphDatabase
from py2neo import Graph
from neomodel import StructuredNode, StringProperty, RelationshipTo, RelationshipFrom, config

# %%
occ_url = "https://ec.europa.eu/esco/api/search?language=en&isInScheme=http://data.europa.eu/esco/concept-scheme/occupations&limit=3561"
response = requests.get(occ_url) #Store the request into a new variable
Occupation_source = response.json()
Occupation = Occupation_source['_embedded']
df_Occupation = pd.DataFrame(Occupation["results"]) #Convert to pandas

# %%
print(df_Occupation.info())
print(df_Occupation["className"].unique())
print(df_Occupation[df_Occupation["className"] == "Concept"]["title"])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3561 entries, 0 to 3560
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   className             3561 non-null   object
#  1   classId               3561 non-null   object
#  2   uri                   3561 non-null   object
#  3   title                 3561 non-null   object
#  4   preferredLabel        3561 non-null   object
#  5   code                  3561 non-null   object
#  6   isInScheme            3561 non-null   object
#  7   broaderOccupation     1241 non-null   object
#  8   _links                3561 non-null   object
#  9   isTopConceptInScheme  1711 non-null   object
#  10  broaderIscoGroup      1701 non-null   object
#  11  broaderConcept        609 non-null    object
# dtypes: object(12)
# memory usage: 334.0+ KB
# None
# ['Occupation' 'Concept']
# 9                                             Accountants
# 11                      Accounting and bookkeeping clerks
# 13                     Accounting associate professionals
# 19                                                 Actors
# 23                           Administration professionals
#                               ...
# 3534      Wood processing and papermaking plant operators
# 3535                      Wood processing plant operators
# 3542                                        Wood treaters
# 3543    Wood treaters, cabinet-makers and related trad...
# 3547       Woodworking-machine tool setters and operators
# Name: title, Length: 619, dtype: object
